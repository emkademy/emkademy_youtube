# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
# !git clone https://github.com/jantic/DeOldify.git
# Out:
# Cloning into 'DeOldify'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 2163 (delta 4), reused 7 (delta 3), pack-reused 2149
# Receiving objects: 100% (2163/2163), 69.40 MiB | 34.13 MiB/s, done.
# Resolving deltas: 100% (980/980), done.

# %%
cd DeOldify/
# Out:
# /content/DeOldify

# %%
# !mkdir models
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth
# Out:
# --2020-11-22 16:28:07--  https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth
# Resolving data.deepai.org (data.deepai.org)... 138.201.36.183
# Connecting to data.deepai.org (data.deepai.org)|138.201.36.183|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255144681 (243M) [application/octet-stream]
# Saving to: ‘./models/ColorizeArtistic_gen.pth’
#
# ./models/ColorizeAr 100%[===================>] 243.32M  31.8MB/s    in 8.2s
#
# 2020-11-22 16:28:15 (29.8 MB/s) - ‘./models/ColorizeArtistic_gen.pth’ saved [255144681/255144681]

# %%
# !pip install -r colab_requirements.txt
# Out:
# ...
#      |████████████████████████████████| 215kB 21.9MB/s
# ...
#      |████████████████████████████████| 133kB 44.5MB/s
# ...
#      |████████████████████████████████| 1.8MB 49.7MB/s
# ...
#      |████████████████████████████████| 7.9MB 59.6MB/s
# ...
#      |████████████████████████████████| 81kB 12.5MB/s
# ...
#      |████████████████████████████████| 61kB 11.2MB/s
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp36-none-any.whl size=6083 sha256=b47547db4b4737acf8bdda6a4a7d90841c10fe89dba5e61c50b3990736df7aa4
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# ...
#   Created wheel for typing: filename=typing-3.7.4.3-cp36-none-any.whl size=26307 sha256=f80d67312c970b9f93b8d605d607e85bd53fcf7db3b1cd65f6a3c1cfe63d9cee
#   Stored in directory: /root/.cache/pip/wheels/2d/04/41/8e1836e79581989c22eebac3f4e70aaac9af07b0908da173be
# Successfully built ffmpeg typing
# ...

# %%
import matplotlib.pyplot as plt
import torch

from deoldify import device
from deoldify.device_id import DeviceId
from deoldify.visualize import get_image_colorizer

print(torch.cuda.is_available())
# Out:
# True

# %%
render_faktor = 35
colorizer = get_image_colorizer(artistic=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
foto_linki = "https://img-s2.onedio.com/id-5a16fd870b68c3ee0ea7e297/rev-0/w-900/h-1123/f-jpg/s-1eeee39ae835d6ffa38782ed55edee8c634953dd.jpg"
colorizer.plot_transformed_image_from_url(url=foto_linki, render_factor=render_faktor, compare=True, watermarked=False)
# Out:
# PosixPath('result_images/image.png')

# %%
renkli_foto = colorizer.get_transformed_image("../1.png", render_factor=render_faktor, watermarked=False)

# %%
renkli_foto.size
# Out:
# (765, 952)

# %%
plt.imshow(renkli_foto)
plt.show()
